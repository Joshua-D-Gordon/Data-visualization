# %% [markdown]
# # Data Science Project: Joshua Gordon

# %% [markdown]
# # Contents:
# * classification model
# * * KNN model to predict a given year between 2015 - 2019 based on nine features
# * * In this project we merged 5 data sets and added the year the survay was taken in
# * * another "sexier" modlel using only strongly correlated featrues
#
# * * Logistic regression model
#
# * regression model
# * * predicting the writing score on a test

# %% [markdown]
# ## part one: Classification model
#
# ##### goals:
# * ***importing and anaylizing data, understanding what we are working with***
# * ***data cleaning***
# * ***spliting the data to test and train sets***
# * ***maximizing our models accuracy***

# %% [markdown]
# #### *importing and anaylizing data, understanding what we are working with*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_2019 = pd.read_csv(r'C:\Users\Joshua Student\Downloads\archive (1)\2019.csv')

df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %% [markdown]
# ## We have managed to import our dataset of world happines report 2019
#
# #### After importing our data I have stummbled across another 4 data sets from previose years (2015 - 2018).
# #### We shall import all these five data sets and proceed to clean the data one data set at a time in order to hopfully merge all the data sets

# %%
df_2019['year'] = 2019

cols_lst = ['Overall rank', 'Country or region', 'Score', 'GDP per capita','Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'year']

df_2019.columns = cols_lst

df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  year
# 0                      0.393  2019
# 1                      0.410  2019
# 2                      0.341  2019
# 3                      0.118  2019
# 4                      0.298  2019

# %% [markdown]
# #### *We shall add a column for each dataset with the year the data was recorded. we shall then try build a classifiction modle*
# #### *that will correctly prredict the year of a given data sample.*
#
# #### *An imortant part of the data cleaning prossess is to make sure all 5 datasets have the same headings we there for shall drop heading that are unique and keep only the headings and data that all 5 data sets share.

# %%
df_2018 = pd.read_csv(r'C:\Users\Joshua Student\Downloads\archive (1)\2018.csv')
df_2018['year'] = 2018

df_2018.columns = cols_lst

df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption  year
# 0                      0.393  2018
# 1                      0.340  2018
# 2                      0.408  2018
# 3                      0.138  2018
# 4                      0.357  2018

# %%
df_2017 = pd.read_csv(r'C:\Users\Joshua Student\Downloads\archive (1)\2017.csv')


df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %% [markdown]
# #### *We can clearly see here that we have irrelivant data that is not shared with our previouse data sets. we shall there for drop them as they are irrelivant for our task at hand*

# %%
df_2017['year'] = 2017
df_2017.drop(['Whisker.high', 'Whisker.low', 'Dystopia.Residual'], axis=1, inplace=True)

temp_lst = list(df_2017)


col_Titles=["Happiness.Rank","Country"] + temp_lst[2:]


df_2017=df_2017.reindex(columns=col_Titles)

df_2017.columns = cols_lst

df_2017.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1            Norway  7.537        1.616463        1.533524
# 1             2           Denmark  7.522        1.482383        1.551122
# 2             3           Iceland  7.504        1.480633        1.610574
# 3             4       Switzerland  7.494        1.564980        1.516912
# 4             5           Finland  7.469        1.443572        1.540247
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                 0.796667                      0.635423    0.362012
# 1                 0.792566                      0.626007    0.355280
# 2                 0.833552                      0.627163    0.475540
# 3                 0.858131                      0.620071    0.290549
# 4                 0.809158                      0.617951    0.245483
#
#    Perceptions of corruption  year
# 0                   0.315964  2017
# 1                   0.400770  2017
# 2                   0.153527  2017
# 3                   0.367007  2017
# 4                   0.382612  2017

# %%
df_2016 = pd.read_csv(r'C:\Users\Joshua Student\Downloads\archive (1)\2016.csv')

df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %% [markdown]
# #### *We can clearly see here that we have irrelivant data that is not shared with our previouse data sets. we shall there for drop them as they are irrelivant for oour task at hand*

# %%
df_2016['year'] = 2016
df_2016.drop(['Lower Confidence Interval','Upper Confidence Interval','Dystopia Residual','Region'] ,axis = 1,inplace=True)

temp_lst = list(df_2016)

col_Titles = ["Happiness Rank","Country"] + temp_lst[2:]

df_2016 = df_2016.reindex(columns=col_Titles)
df_2016.columns = cols_lst

df_2016.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Denmark  7.526         1.44178         1.16374
# 1             2       Switzerland  7.509         1.52733         1.14524
# 2             3           Iceland  7.501         1.42666         1.18326
# 3             4            Norway  7.498         1.57744         1.12690
# 4             5           Finland  7.413         1.40598         1.13464
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                  0.79504                       0.57941     0.44453
# 1                  0.86303                       0.58557     0.41203
# 2                  0.86733                       0.56624     0.14975
# 3                  0.79579                       0.59609     0.35776
# 4                  0.81091                       0.57104     0.41004
#
#    Perceptions of corruption  year
# 0                    0.36171  2016
# 1                    0.28083  2016
# 2                    0.47678  2016
# 3                    0.37895  2016
# 4                    0.25492  2016

# %%
df_2015 = pd.read_csv(r'C:\Users\Joshua Student\Downloads\archive (1)\2015.csv')

df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# #### *We can clearly see here that we have irrelivant data that is not shared with our previouse data sets. we shall there for drop them as they are irrelivant for oour task at hand*

# %%
df_2015['year'] = 2015
lst = list(df_2015)
df_2015.drop([lst[1], lst[4], lst[-2]], axis = 1, inplace=True)

lst = list(df_2015)
col_Titles = ["Happiness Rank", "Country"] + lst[2:]

df_2015 = df_2015.reindex(columns=col_Titles)
df_2015.columns = cols_lst

df_2015.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1       Switzerland  7.587         1.39651         1.34951
# 1             2           Iceland  7.561         1.30232         1.40223
# 2             3           Denmark  7.527         1.32548         1.36058
# 3             4            Norway  7.522         1.45900         1.33095
# 4             5            Canada  7.427         1.32629         1.32261
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                  0.94143                       0.66557     0.41978
# 1                  0.94784                       0.62877     0.14145
# 2                  0.87464                       0.64938     0.48357
# 3                  0.88521                       0.66973     0.36503
# 4                  0.90563                       0.63297     0.32957
#
#    Perceptions of corruption  year
# 0                    0.29678  2015
# 1                    0.43630  2015
# 2                    0.34139  2015
# 3                    0.34699  2015
# 4                    0.45811  2015

# %% [markdown]
# ## data cleaning
#
# #### *We have successfuly manged to import and clean our 5 data sets in order to merge the data sets in to one big data frame*

# %%
all_years_data = [df_2019, df_2018, df_2017, df_2016, df_2015]

df = pd.concat(all_years_data)

df.head(1000)
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1           Finland  7.769         1.34000         1.58700
# 1               2           Denmark  7.600         1.38300         1.57300
# 2               3            Norway  7.554         1.48800         1.58200
# 3               4           Iceland  7.494         1.38000         1.62400
# 4               5       Netherlands  7.488         1.39600         1.52200
# ..            ...               ...    ...             ...             ...
# 153           154            Rwanda  3.465         0.22208         0.77370
# 154           155             Benin  3.340         0.28665         0.35386
# 155           156             Syria  3.006         0.66320         0.47489
# 156           157           Burundi  2.905         0.01530         0.41587
# 157           158              Togo  2.839         0.20868         0.13995
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.98600                       0.59600     0.15300
# 1                    0.99600                       0.59200     0.25200
# 2                    1.02800                       0.60300     0.27100
# 3                    1.02600                       0.59100     0.35400
# 4                    0.99900                       0.55700     0.32200
# ..                       ...                           ...         ...
# 153                  0.42864                       0.59201     0.55191
# 154                  0.31910                       0.48450     0.08010
# 155                  0.72193                       0.15684     0.18906
# 156                  0.22396                       0.11850     0.10062
# 157                  0.28443                       0.36453     0.10731
#
#      Perceptions of corruption  year
# 0                      0.39300  2019
# 1                      0.41000  2019
# 2                      0.34100  2019
# 3                      0.11800  2019
# 4                      0.29800  2019
# ..                         ...   ...
# 153                    0.22628  2015
# 154                    0.18260  2015
# 155                    0.47179  2015
# 156                    0.19727  2015
# 157                    0.16681  2015
#
# [782 rows x 10 columns]

# %%
df.shape
# Out:
# (782, 10)

# %% [markdown]
# ## ***Above we have used the shape function and can conclude that we have 10 features ad 782 rows of data***

# %% [markdown]
# # Lets make sure we understand all our features:
# ### overall rank: the rank of that year out of all the countrys
# ### country of region: the country that was ranked
# ### score: the overall score
# ### GDP per capita: Gross domestic product final good and services produced value
# ### socail support: the score for social support
# ### healthy life expectancy: the score for life expectancy
# ### freedom of choices: the score for freedom
# ### generosity: the score on the survay for generosity
# ### Perceptions of corruption: score for perceptions of corruption
# ### year: the year the surrvay was done in
#
# # Over all we have ten features and 782 rows of data

# %%
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    782.000000  782.000000      782.000000      782.000000
# mean      78.698210    5.379018        0.916047        1.078392
# std       45.182384    1.127456        0.407340        0.329548
# min        1.000000    2.693000        0.000000        0.000000
# 25%       40.000000    4.509750        0.606500        0.869363
# 50%       79.000000    5.322000        0.982205        1.124735
# 75%      118.000000    6.189500        1.236187        1.327250
# max      158.000000    7.769000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               782.000000                    782.000000  782.000000
# mean                  0.612416                      0.411091    0.178526
# std                   0.248309                      0.152880    0.119115
# min                   0.000000                      0.000000    0.000000
# 25%                   0.440183                      0.309768    0.084860
# 50%                   0.647310                      0.431000    0.155219
# 75%                   0.808000                      0.531000    0.246864
# max                   1.141000                      0.724000    0.838075
#
#        Perceptions of corruption         year
# count                 781.000000   782.000000
# mean                    0.165536  2016.993606
# std                     0.127410     1.417364
# min                     0.000000  2015.000000
# 25%                     0.067860  2016.000000
# 50%                     0.128000  2017.000000
# 75%                     0.236930  2018.000000
# max                     0.819710  2019.000000

# %% [markdown]
# #### *We have merged the data and got a quick description of our new 5 in 1 data set*

# %%
df.isnull().sum()
#checking to see which values are null
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# year                            0
# dtype: int64

# %% [markdown]
# #### Checking for null values as this could mess around later on when we try and make a modle

# %%
df['Perceptions of corruption'] = df['Perceptions of corruption'].fillna(0)

# %% [markdown]
# #### ***fillling missing values***

# %%
df.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# year                            0
# dtype: int64

# %% [markdown]
# #### Fixing the null values and double checking see have corrected the data

# %%
import seaborn as sns

plt.figure(figsize=(13, 10))
sns.heatmap(df.corr(), annot = True);

# %%
df.corr()['year']
# Out:
# Overall rank                   -0.007768
# Score                           0.007065
# GDP per capita                  0.019768
# Social support                  0.367431
# Healthy life expectancy         0.130302
# Freedom to make life choices    0.010353
# Generosity                      0.150721
# Perceptions of corruption      -0.427954
# year                            1.000000
# Name: year, dtype: float64

# %% [markdown]
# # Important Analiysis
#
# * ***Let us notic that our countrys have not shown up in the correlation graph as they are objects of the type String and we would need to manually make them in to numric values***
#
# ### ***most importantly we shall notice that there is a weak correlation between the feature year and the other features. We can there for expect for our modle to have a lower accuracy score than if the features were highly correlated***

# %% [markdown]
# # spliting the data to test and train sets

# %%
from sklearn.neighbors import KNeighborsClassifier

X = df[['Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
y = df['year']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)


score = classifier.score(X_test, y_test)
print(score)
# Out:
# 0.10191082802547771

# %% [markdown]
# ## ***We have imported our clasifier model and split our data in to training and testing sets using the standard 20/80 split. We then defined a clasifier of the type KNN and fitted our modle with our training sets using the standard 5 knn***
#
# ### We want our model to recive all the other 9 features and predict the year the survey was taken in
#
# ### We used our score metric on the test sets and our classifier scores with around
#
# # 10.19% accuracy
#
# ## this isnt supprising right? I mean we knew from the corrolation heatmap that our classifier's accuracy woudnt be as high due to the correlation of the features. But its still worth somthing right? I mean all this hard work it has to be worth somthing and 10.19% isnt that bad right?
#
# # WRONG!
#
# ## when someone claims to have an outstanding model we should always ask what is the distribution of the classes.
#
# ## a good example is someone may say they have a model that predicts correctly if a bag at the airport has a bomb in it, at an accuracy of 99%. 99% sounds amazing right? but if only 1 in 100,000 bags has a bomb in it than suddnly this 99% is much less impressive as any "dummy" could get a better accuracy score by just saying there is no bomb in each bag and would get a 99.99% accuracy score.

# %% [markdown]
# ### let me explain.
#
# ## ***I would like to introduce our dummy clasifier***
#
# ![download.jfif](attachment:download.jfif)
#
# ### *A dummy clasifier is a benchmark that if not passed we could all agree that our model is usless.*
#
# ## ***Lets clarify our dummy clasifier***
#
# ### We can say our clasifier is trying to predict a given year OUT OF 5 years. Meaning there are 5 options and no more than 5. We can therefor say that a "Dummy classifier" has a 0 risk 0.2 chance of just returning the year 2015 and would get an accuracy score of 20%. In other words anything below 20.00% is usless as any "Dummy" could just print the most freqent year and produce better results.
#
# ### therefor we come to a conclusion that our model (for the moment) is usless

# %%
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy='most_frequent')
dummy_clf.fit(X, y)
DummyClassifier(strategy='most_frequent')

dummy_clf.score(X, y)
# Out:
# 0.2020460358056266

# %% [markdown]
# # above we have imported sklearns dummy classifier to generate our dummy classifier. however we thought given the survey was given to a certain amount of countrys each year we came to the conclusion that the dummy classifier would be 20% (1 out of the 5 years) so why is it that its 20.20%?

# %%
df.groupby('year').size()
# Out:
# year
# 2015    158
# 2016    157
# 2017    155
# 2018    156
# 2019    156
# dtype: int64

# %% [markdown]
# ### ***Above we can see that the number of countrys that participated in the survay each year are not eqaul***

# %%
lst = [df_2015, df_2016, df_2017, df_2018, df_2019]
maxi = 0
sumi = 0
year = 2015 - 1
for i in lst:
    shape = list(i.shape)
    print(shape)
    sumi+=shape[0]
    if(shape[0]>maxi):
        maxi = shape[0]
        year+=1


        
print("the class weights are not eqaul, meaning we assumed wrong and each year not all countrys participated in the survay")
print("our max amount of countrys survayed in year: " , year , "with the amount of: " , maxi , " with a total of " , sumi )

print("we can there for say the correct dummy classifier is indeed: ",maxi ,"/" , sumi ," = " , maxi/(sumi))
# Out:
# [158, 10]
# [157, 10]
# [155, 10]
# [156, 10]
# [156, 10]
# the class weights are not eqaul, meaning we assumed wrong and each year not all countrys participated in the survay
# our max amount of countrys survayed in year:  2015 with the amount of:  158  with a total of  782
# we can there for say the correct dummy classifier is indeed:  158 / 782  =  0.2020460358056266

# %% [markdown]
# ### ***Because we merged 5 data sets and not all the data sets had the same amount of data we were abit off with our dummy classifier estimate. However our dummy clasifier is 20.20% meaning anything below or eqaul is usless***
#
# ## Its good that we double checked and have a better understanding of the benchmark we need to pass

# %%
df['Country or region'] = df['Country or region'].str.title()

countrys = list(df['Country or region'].unique())

# %%
nums = list(range(1,len(countrys)+1))


dic = dict(zip(countrys, nums))

# %% [markdown]
# ### ***let us try improve our modle by adding the countrys, above we have made two lists: one of countrys and the other of numbers 1 - 169 representing all the countrys. we have merged them in to a dictinary and will add the new values to our dataset***

# %%
df['Country of region to num'] = df['Country or region'].map(dic)
df.head(1000)
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 0               1           Finland  7.769         1.34000         1.58700
# 1               2           Denmark  7.600         1.38300         1.57300
# 2               3            Norway  7.554         1.48800         1.58200
# 3               4           Iceland  7.494         1.38000         1.62400
# 4               5       Netherlands  7.488         1.39600         1.52200
# ..            ...               ...    ...             ...             ...
# 153           154            Rwanda  3.465         0.22208         0.77370
# 154           155             Benin  3.340         0.28665         0.35386
# 155           156             Syria  3.006         0.66320         0.47489
# 156           157           Burundi  2.905         0.01530         0.41587
# 157           158              Togo  2.839         0.20868         0.13995
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.98600                       0.59600     0.15300
# 1                    0.99600                       0.59200     0.25200
# 2                    1.02800                       0.60300     0.27100
# 3                    1.02600                       0.59100     0.35400
# 4                    0.99900                       0.55700     0.32200
# ..                       ...                           ...         ...
# 153                  0.42864                       0.59201     0.55191
# 154                  0.31910                       0.48450     0.08010
# 155                  0.72193                       0.15684     0.18906
# 156                  0.22396                       0.11850     0.10062
# 157                  0.28443                       0.36453     0.10731
#
#      Perceptions of corruption  year  Country of region to num
# 0                      0.39300  2019                       1.0
# 1                      0.41000  2019                       2.0
# 2                      0.34100  2019                       3.0
# 3                      0.11800  2019                       4.0
# 4                      0.29800  2019                       5.0
# ..                         ...   ...                       ...
# 153                    0.22628  2015                     152.0
# 154                    0.18260  2015                     102.0
# 155                    0.47179  2015                     149.0
# 156                    0.19727  2015                     145.0
# 157                    0.16681  2015                     139.0
#
# [782 rows x 11 columns]

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df.corr(), annot = True);

# %% [markdown]
# ## ***Here we can see that our countrys of region to num has been inserted to our correlation heatmap***

# %%
from sklearn.neighbors import KNeighborsClassifier

X = df[['Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Country of region to num']]
y = df['year']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)
print(score)
# Out:
# 0.2356687898089172

# %% [markdown]
# ## ***well above we can see that we have inproved our classifier by over 10% to 23.56%! and we have now past our dummy clasifier meaning we are not usless! YAY :)***

# %% [markdown]
# #### lets see what test size would give us the best accuracy score! so we can improve our 23.5%

# %%
lst_max_test_size = []
for i in np.arange(0.1,1,0.01):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state = 0)

    classifier = KNeighborsClassifier(n_neighbors = 5)

    classifier.fit(X_train, y_train)

    score = classifier.score(X_test, y_test)
    
    lst_max_test_size.append(score)

# %% [markdown]
# ### Above we have performed a loop starting from a test size of 10% and moving up 1% each new classifer, all our score results have been appended to a list

# %%
plt.figure(figsize=(10,8))

plt.plot(np.arange(0.1,1,0.01),lst_max_test_size)
plt.xlabel("test size")
plt.ylabel("accuracy")
plt.title("accuracy as a function of test size")
# Out:
# Text(0.5, 1.0, 'accuracy as a function of test size')

# %%
best_test_size = 0.1
accuracy_max = max(lst_max_test_size)
for i in lst_max_test_size:
    if(i == accuracy_max):
        save = best_test_size
    best_test_size += 0.01
print(save)
# Out:
# 0.40000000000000024

# %% [markdown]
# #### Good work so far. we have ploted a graph showing all the results from our loops we an clearly see that at a test size of 40% (0.4 on the graph) we will revice the maximin resluts. lets apply this

# %%
from sklearn.neighbors import KNeighborsClassifier

X = df[['Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Country of region to num']]
y = df['year']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)


print(score)
# Out:
# 0.25878594249201275

# %% [markdown]
# ### Boom! from 23.56% to 25.87% thats a nice increase. let us try adjust our k value for our KNN in order to maximize even more our clasifier

# %%
lst_max_knn = []
for i in np.arange(1,50):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 0)

    classifier = KNeighborsClassifier(n_neighbors = i)

    classifier.fit(X_train, y_train)

    score = classifier.score(X_test, y_test)
    
    lst_max_knn.append(score)

# %% [markdown]
# ### ***Above we have yet again loops this time for 50 times and split the data with a 40/60 split test (As we saw this gives us the best results) only this time each loop the number of neigbors will be ajusted from 1 to 50. the results will be stored in a list and we will see the best KNN for our model***

# %%
plt.figure(figsize=(10,8))

plt.plot(np.arange(1,50),lst_max_knn)
plt.xlabel("KNN")
plt.ylabel("accuracy")
plt.title("accuracy as a function of KNN")
# Out:
# Text(0.5, 1.0, 'accuracy as a function of KNN')

# %%
max_value = 0
kkn_ks = 0
count = 0
for knn_score in  lst_max_knn:
    if(knn_score > max_value):
        max_value = knn_score
        knn_ks = count + 1
    count+=1
        
print(max_value)
print(knn_ks)
# Out:
# 0.25878594249201275
# 5

# %% [markdown]
# ### We can see from our plotted graph that our best number of neigbors is 5 wich is what we had previously

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)
print(score)
# Out:
# 0.25878594249201275

# %% [markdown]
# ###  ***Below we are going to do a K cross validation***
#
# #### This will help us make sure our model is reliable

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
folds = KFold(n_splits = 10, shuffle = False)
scores = cross_val_score(classifier, X_train, y_train, scoring='accuracy', cv=folds)
scores.mean()
# Out:
# 0.24949121184088807

# %%
folds = KFold(n_splits = 5, shuffle = False)
scores = cross_val_score(classifier, X_train, y_train, scoring='accuracy', cv=folds)
scores
# Out:
# array([0.20212766, 0.21276596, 0.26595745, 0.25531915, 0.33333333])

# %%
scores.mean()
# Out:
# 0.25390070921985813

# %% [markdown]
# #### Above we have tryed a 5 fold and 10 fold validation as we can see it is better for us to use 5 in this case and we confirm our modle is reliable with an average of 25.17% accuracy

# %% [markdown]
# ## is there a problem with how we have built our model? below i shall explain.

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df.corr(), annot = True);

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769             1.0           1.587
# 1             2           Denmark  7.600             1.0           1.573
# 2             3            Norway  7.554             1.0           1.582
# 3             4           Iceland  7.494             1.0           1.624
# 4             5       Netherlands  7.488             1.0           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  year  Country of region to num
# 0                      0.393  2019                       1.0
# 1                      0.410  2019                       2.0
# 2                      0.341  2019                       3.0
# 3                      0.118  2019                       4.0
# 4                      0.298  2019                       5.0

# %% [markdown]
# ## Above is our correlation heat map as well as the head of our 5 in 1 data frame.
#
# ## looking at the year column it seems the years are much bigger number wise inregards to other features. could this be messing around with our model?
#
#
# # lets manually normilize the year feature and instead of using big year numbers we will replace it with 1,2,3,4,5 instead of 2015,2016,2017,2018,2019

# %%
df['year'].replace({2015: 1, 2016: 2, 2017: 3, 2018: 4 , 2019: 5}, inplace=True)

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  year  Country of region to num
# 0                      0.393     5                       1.0
# 1                      0.410     5                       2.0
# 2                      0.341     5                       3.0
# 3                      0.118     5                       4.0
# 4                      0.298     5                       5.0

# %% [markdown]
# ## ***We can see the years have been changed and if there was a problem before because of the big numbers it should now be less of an issue***

# %%
from sklearn.neighbors import KNeighborsClassifier

X = df[['Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Country of region to num']]
y = df['year']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)
print(score)
# Out:
# 0.25878594249201275

# %% [markdown]
# # 25.87%
#
# ## This is the same that we got befor meaning that we do not have a problem with the numbers and there was no need to manually normalize. however it is good that we double checked

# %%
df['year'].replace({1: 2015, 2:2016, 3:2017, 4:2018 , 5:2019}, inplace=True)

# %%
X = df[['Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption','Country of region to num']]
y = df['year']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)
print(score)
# Out:
# 0.25878594249201275

# %% [markdown]
# # 25.87% accuracy

# %% [markdown]
# ## *This may not be an impressive result to show off, however i am confident that i understood the data and handled it well. also due to the correlation we were not expecting amazing results.*
#
# # Below we shall show the distrebution of the years of each feature and see that they are extremly similar and not that diffrent wich is not a huge supprise.

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  year  Country of region to num
# 0                      0.393  2019                       1.0
# 1                      0.410  2019                       2.0
# 2                      0.341  2019                       3.0
# 3                      0.118  2019                       4.0
# 4                      0.298  2019                       5.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

def histogram(lst_features):
    for f in lst_features:

        # set seed for reproducing
        np.random.seed(42)
        n = 5000

        #2015
        mean_2015 = df_2015[f].mean()
        sd_2015 = df_2015[f].std()
        hist_2015 = np.random.normal(mean_2015, sd_2015, n)

        #2016
        mean_2016 = df_2016[f].mean()
        sd_2016 = df_2016[f].std()
        hist_2016 = np.random.normal(mean_2016, sd_2016, n)

        #2017
        mean_2017 = df_2017[f].mean()
        sd_2017 = df_2017[f].std()
        hist_2017 = np.random.normal(mean_2017, sd_2017, n)

        #2018
        mean_2018 = df_2018[f].mean()
        sd_2018 = df_2018[f].std()
        hist_2018 = np.random.normal(mean_2018, sd_2018, n)

        #2019
        mean_2019 = df_2019[f].mean()
        sd_2019 = df_2019[f].std()
        hist_2019 = np.random.normal(mean_2019, sd_2019, n)

        plt.figure(figsize=(13,8))
        sns.distplot(hist_2015, hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = "2015")
        sns.distplot(hist_2016, hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = "2016")
        sns.distplot(hist_2017, hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = "2017")
        sns.distplot(hist_2018, hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = "2018")
        sns.distplot(hist_2019, hist = False, kde = True,kde_kws = {'shade': True, 'linewidth': 3}, label = "2019")


        plt.xlabel(f, size=14)
        plt.ylabel("Amount", size=14)
        plt.title(f + " vs Amount")
        plt.legend(loc='upper right')


        
        

        
lst_fs = list(df)
lst_fs.remove('Country or region')
lst_fs.remove('Country of region to num')
lst_fs.remove('year')

histogram(lst_fs)

# %% [markdown]
# # Confusion matrix
#
# ## Below we are going to show the confusion matrix of our model this should give us a good indicator of how our model predicts TT, FF, TF, FT

# %%
from sklearn.metrics import plot_confusion_matrix

fig, ax = plt.subplots(figsize=(13, 10))
plot_confusion_matrix(classifier, X_test, y_test, ax=ax,cmap=plt.cm.Blues)

# %% [markdown]
# # Lets normalzie our conffusion mattrix

# %%
from sklearn.metrics import plot_confusion_matrix

fig, ax = plt.subplots(figsize=(13, 10))
plot_confusion_matrix(classifier, X_test, y_test, ax=ax,cmap=plt.cm.Blues,normalize='true')

# %% [markdown]
# ## Above we can see that our model that recives all nine features and needs to predcit the given year the survay was taken in mainly gets them wrong apart from year 2019 where the TT rate is 66%
#
# ## thiss is not supprising as we saw ealier in the distribution graphs the features dont vary that much from year to year

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df.corr(), annot = True);

# %% [markdown]
# ## ***Above we can see that social support, generosity ,Healthy life expectancy and perceptions of curruption is highly correlated with the year, therefor lets try run a quick modle with ONLY these four features***
#
# ## meaning our *new* model will recive instead of all nine other features it will recive only these four features and predict the year the survay was taken in

# %%
X = df[['Social support', 'Perceptions of corruption','Generosity','Healthy life expectancy']]
y = df['year']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)

print(score)
# Out:
# 0.4504792332268371

# %% [markdown]
# #### Above we can see we have a 45.04% wich is higher than our current classifier

# %%
from sklearn.metrics import plot_confusion_matrix

fig, ax = plt.subplots(figsize=(13, 10))
plot_confusion_matrix(classifier, X_test, y_test, ax=ax,cmap=plt.cm.Blues,normalize='true')

# %% [markdown]
# ## Above we can see our current confusion matrix of our *new* model. its TT rate is much better but lets see how we can improve it even more

# %%
lst_max_test_size = []
for i in np.arange(0.01,1,0.01):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state = 0)

    classifier = KNeighborsClassifier(n_neighbors = 5)

    classifier.fit(X_train, y_train)

    score = classifier.score(X_test, y_test)
    
    lst_max_test_size.append(score)
    
best_test_size = 0.01
accuracy_max = max(lst_max_test_size)
for i in lst_max_test_size:
    if(i == accuracy_max):
        save = best_test_size
    best_test_size += 0.01
print(save)
# Out:
# 0.09999999999999999

# %%
plt.plot(np.arange(0.01,1,0.01),lst_max_test_size)
plt.xlabel('Test size')
plt.ylabel('accuracy')
plt.title('accuracy VS test size')
# Out:
# Text(0.5, 1.0, 'accuracy VS test size')

# %% [markdown]
# ## Above I have written a code that loops from 1% test size to 100% and recived the best test size split value for our new model wich is 10%

# %%
X = df[['Social support', 'Perceptions of corruption','Generosity','Healthy life expectancy']]
y = df['year']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)

print(score)
# Out:
# 0.5189873417721519

# %% [markdown]
# ## below we shall do the same for our KNN

# %%
lst_max_knn = []
for i in np.arange(1,50):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state = 0)

    classifier = KNeighborsClassifier(n_neighbors = i)

    classifier.fit(X_train, y_train)

    score = classifier.score(X_test, y_test)
    
    lst_max_knn.append(score)
    
max_value = 0
kkn_ks = 0
count = 0
for knn_score in  lst_max_knn:
    if(knn_score > max_value):
        max_value = knn_score
        knn_ks = count + 1
    count+=1
        
print(max_value)
print(knn_ks)
# Out:
# 0.5443037974683544
# 7

# %%
plt.plot(np.arange(1,50),lst_max_knn)
plt.xlabel('KNN')
plt.ylabel('accuracy')
plt.title('accuracy VS KNN')
# Out:
# Text(0.5, 1.0, 'accuracy VS KNN')

# %%
X = df[['Social support', 'Perceptions of corruption','Generosity','Healthy life expectancy']]
y = df['year']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 7)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)

print(score)
# Out:
# 0.5443037974683544

# %% [markdown]
# ## We have slowly imporoved our new model and come to an accuracy rate of 54.43%

# %%
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy='most_frequent')
dummy_clf.fit(X, y)
DummyClassifier(strategy='most_frequent')

dummy_clf.score(X, y)
# Out:
# 0.2020460358056266

# %% [markdown]
# ### ***Much better than our dummy classifer***
#
# ## below we can see our new confusion matrix

# %%
from sklearn.metrics import plot_confusion_matrix

fig, ax = plt.subplots(figsize=(13, 10))
plot_confusion_matrix(classifier, X_test, y_test, ax=ax,cmap=plt.cm.Blues,normalize='true')

# %% [markdown]
# # ROC
#
# ## Doing a ROC graph and analyis with multipe classes such as years (2015-2019) is abit complicated therefor below we will make a new model that predicts a "good" GDP score
#
# ## below we shal define a good GPD score as a score above the average GDP
#
# ## we shall create our modle , split the data, find the best test size as well as the best KKN value. we shall than show the confusion matrix as well as the ROC curve

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769             1.0           1.587
# 1             2           Denmark  7.600             1.0           1.573
# 2             3            Norway  7.554             1.0           1.582
# 3             4           Iceland  7.494             1.0           1.624
# 4             5       Netherlands  7.488             1.0           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  year  Country of region to num
# 0                      0.393  2019                       1.0
# 1                      0.410  2019                       2.0
# 2                      0.341  2019                       3.0
# 3                      0.118  2019                       4.0
# 4                      0.298  2019                       5.0

# %%
mean = df['GDP per capita'].mean()

# %%
df['GDP per capita'] = np.where((df['GDP per capita'] >= mean),1,df['GDP per capita'])
df['GDP per capita'] = np.where((df['GDP per capita'] < mean),0,df['GDP per capita'])
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769             1.0           1.587
# 1             2           Denmark  7.600             1.0           1.573
# 2             3            Norway  7.554             1.0           1.582
# 3             4           Iceland  7.494             1.0           1.624
# 4             5       Netherlands  7.488             1.0           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption  year  Country of region to num
# 0                      0.393  2019                       1.0
# 1                      0.410  2019                       2.0
# 2                      0.341  2019                       3.0
# 3                      0.118  2019                       4.0
# 4                      0.298  2019                       5.0

# %%
X = df[['Healthy life expectancy']]
y = df['GDP per capita']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)

print(score)
# Out:
# 0.7667731629392971

# %%
lst_max_test_size = []
for i in np.arange(0.01,1,0.01):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state = 0)

    classifier = KNeighborsClassifier(n_neighbors = 5)

    classifier.fit(X_train, y_train)

    score = classifier.score(X_test, y_test)
    
    lst_max_test_size.append(score)
    
best_test_size = 0.01
accuracy_max = max(lst_max_test_size)
for i in lst_max_test_size:
    if(i == accuracy_max):
        save = best_test_size
    best_test_size += 0.01
print(save)
fig, ax = plt.subplots(figsize=(13, 10))
plt.plot(np.arange(0.01,1,0.01),lst_max_test_size)
plt.xlabel('Test size')
plt.ylabel('accuracy')
plt.title('accuracy VS test size')
# Out:
# 0.02
# Text(0.5, 1.0, 'accuracy VS test size')

# %%
X = df[['Healthy life expectancy']]
y = df['GDP per capita']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.02, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 5)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)

print(score)
# Out:
# 0.875

# %%
lst_max_knn = []
for i in np.arange(1,100):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state = 0)

    classifier = KNeighborsClassifier(n_neighbors = i)

    classifier.fit(X_train, y_train)

    score = classifier.score(X_test, y_test)
    
    lst_max_knn.append(score)
    
max_value = 0
kkn_ks = 0
count = 0
for knn_score in  lst_max_knn:
    if(knn_score > max_value):
        max_value = knn_score
        knn_ks = count + 1
    count+=1
        
print(max_value)
print(knn_ks)
# Out:
# 0.7848101265822784
# 3

# %%
fig, ax = plt.subplots(figsize=(13, 10))
plt.plot(np.arange(1,100),lst_max_knn)
plt.xlabel('KNN')
plt.ylabel('accuracy')
plt.title('accuracy VS KNN')
# Out:
# Text(0.5, 1.0, 'accuracy VS KNN')

# %%
X = df[['Healthy life expectancy']]
y = df['GDP per capita']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.02, random_state = 0)

classifier = KNeighborsClassifier(n_neighbors = 3)

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)

print(score)
# Out:
# 0.875

# %%
dummy_clf = DummyClassifier(strategy='most_frequent')
dummy_clf.fit(X, y)
DummyClassifier(strategy='most_frequent')

dummy_clf.score(X, y)
# Out:
# 0.5524296675191815

# %% [markdown]
# ## ***Above we have found the best test size of 0.02 and KNN of 3 with an accuracy score of 87.5% wich is better than our 55.24% dummy classifier***

# %%
fig, ax = plt.subplots(figsize=(13, 10))
plot_confusion_matrix(classifier, X_test, y_test, ax=ax,cmap=plt.cm.Blues,normalize='true')

# %%
from sklearn.metrics import roc_curve, roc_auc_score

y_score1 = classifier.predict_proba(X_test)[:,1]

false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, y_score1)

print('roc_auc_score for KNN: ', roc_auc_score(y_test, y_score1))

fig, ax = plt.subplots(figsize=(13, 10))
plt.title('ROC KNN')
plt.plot(false_positive_rate, true_positive_rate)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# roc_auc_score for KNN:  0.8214521252254434

# %% [markdown]
# ### End of KNN

# %% [markdown]
# # Logistc regression

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df.corr(), annot = True);

# %%
lst = list(df)
lst.remove('Country or region')
lst.remove('GDP per capita')
print(lst)
# Out:
# ['Overall rank', 'Score', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'year', 'Country of region to num']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

X = df[lst]
y = df['GDP per capita']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state = 0)

model =LogisticRegression(solver='liblinear')

model.fit(X_train, y_train)  

model.score(X_test, y_test)
# Out:
# 0.802547770700637

# %% [markdown]
# ## our model will also try predict a good or bad GDP

# %%
dummy_clf = DummyClassifier(strategy='most_frequent')
dummy_clf.fit(X, y)
DummyClassifier(strategy='most_frequent')

dummy_clf.score(X, y)
# Out:
# 0.5524296675191815

# %%
df['GDP per capita'].value_counts()
# Out:
# 1.0    432
# 0.0    350
# Name: GDP per capita, dtype: int64

# %%
X = df[lst]
y = df['GDP per capita']

lst_max_test_size = []

for i in np.arange(0.1,1,0.01):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state = 0)

    model =LogisticRegression(solver='liblinear')

    model.fit(X_train, y_train)  
     

    lst_max_test_size.append(model.score(X_test, y_test))
best_test_size = 0.1
accuracy_max = max(lst_max_test_size)
for i in lst_max_test_size:
    if(i == accuracy_max):
        save = best_test_size
    best_test_size += 0.01
print(save)
fig, ax = plt.subplots(figsize=(13, 10))
plt.plot(np.arange(0.1,1,0.01),lst_max_test_size)
plt.xlabel('Test size')
plt.ylabel('accuracy')
plt.title('accuracy VS test size')
# Out:
# 0.5800000000000004
# Text(0.5, 1.0, 'accuracy VS test size')

# %%
X = df[lst]
y = df['GDP per capita']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.58, random_state = 0)

model =LogisticRegression(solver='liblinear')

model.fit(X_train, y_train)

model.score(X_test, y_test)
# Out:
# 0.8436123348017621

# %%
l = []
for i in range(1,100):
    
    X = df[lst]
    y = df['GDP per capita']

    X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.58, random_state = i)

    model =LogisticRegression(solver='liblinear')

    model.fit(X_train, y_train)

    s = model.score(X_test, y_test)
    l.append(s)
plt.plot(range(1,100),l)
print(max(l))
print(l.index(max(l))+1)
# Out:
# 0.8678414096916299
# 64

# %%
X = df[lst]
y = df['GDP per capita']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.58, random_state = 64)

model =LogisticRegression(solver='liblinear')

model.fit(X_train, y_train)

model.score(X_test, y_test)
# Out:
# 0.8678414096916299

# %% [markdown]
# ## Confusion matrix

# %%
fig, ax = plt.subplots(figsize=(13, 10))
plot_confusion_matrix(model, X_test, y_test, ax=ax,cmap=plt.cm.Blues,normalize='true')

# %%
from sklearn.metrics import roc_curve, roc_auc_score

y_score1 = model.predict_proba(X_test)[:,1]

false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, y_score1)

print('ROC score for Logistic regression: ', roc_auc_score(y_test, y_score1))

fig, ax = plt.subplots(figsize=(13, 10))
plt.title('Logistic regression')
plt.plot(false_positive_rate, true_positive_rate)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# ROC score for Logistic regression:  0.9336106223004319

# %% [markdown]
# # End of Classification

# %% [markdown]
# # Regresion Model
#
# ## part two: Classification model
#
# ##### goals:
# * ***importing and anaylizing data, understanding what we are working with***
# * ***data cleaning***
# * ***spliting the data to test and train sets***
# * ***maximizing our models accuracy***

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_students = pd.read_csv(r'C:\Users\Joshua Student\Downloads\archive (2)\StudentsPerformance.csv')
df_students.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_students.info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]>

# %% [markdown]
# # We shall drop race/ethnicity as we have no idea what this means (The publisher of this dataset also could not give any insight)

# %%
temp_lst = list(df_students)
df_students.drop([temp_lst[1]], axis=1, inplace=True)
df_students.head(5)
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ## ***Let us see the correlation heatmap***

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df_students.corr(), annot = True);

# %% [markdown]
# ## it seems like our correlations can only indentify the scores, we will have to manually change data to numrical values.

# %%
df_students['male'] = df_students.gender.map({'female':0, 'male':1})
df_students.head()
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score  male
# 0          72             72             74     0
# 1          69             90             88     0
# 2          90             95             93     0
# 3          47             57             44     1
# 4          76             78             75     1

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df_students.corr(), annot = True);

# %%
df_students.head(10)
df_students.groupby(['lunch']).count()
# Out:
#               gender  parental level of education  test preparation course  \
# lunch
# free/reduced     355                          355                      355
# standard         645                          645                      645
#
#               math score  reading score  writing score  male
# lunch
# free/reduced         355            355            355   355
# standard             645            645            645   645

# %%
df_students['lunch_cost'] = df_students.lunch.map({'standard':1, 'free/reduced':0})
df_students.head(5)
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score  male  lunch_cost
# 0          72             72             74     0           1
# 1          69             90             88     0           1
# 2          90             95             93     0           1
# 3          47             57             44     1           0
# 4          76             78             75     1           1

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df_students.corr(), annot = True);

# %%
#much better

# %%
df_students.groupby(['test preparation course']).count()
# Out:
#                          gender  parental level of education  lunch  \
# test preparation course
# completed                   358                          358    358
# none                        642                          642    642
#
#                          math score  reading score  writing score  male  \
# test preparation course
# completed                       358            358            358   358
# none                            642            642            642   642
#
#                          lunch_cost
# test preparation course
# completed                       358
# none                            642

# %%
#we can see there are two types of lunch people so we will also try and make these values numric
df_students['preparation_status'] = df_students['test preparation course'].map({'completed':1 , 'none':0})

df_students.head(5)
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score  male  lunch_cost  \
# 0          72             72             74     0           1
# 1          69             90             88     0           1
# 2          90             95             93     0           1
# 3          47             57             44     1           0
# 4          76             78             75     1           1
#
#    preparation_status
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   0

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df_students.corr(), annot = True);

# %% [markdown]
# ## We have mapped above the lunch, gender and preperation to numric values

# %%
df_students.groupby(['parental level of education']).count()
# Out:
#                              gender  lunch  test preparation course  \
# parental level of education
# associate's degree              222    222                      222
# bachelor's degree               118    118                      118
# high school                     196    196                      196
# master's degree                  59     59                       59
# some college                    226    226                      226
# some high school                179    179                      179
#
#                              math score  reading score  writing score  male  \
# parental level of education
# associate's degree                  222            222            222   222
# bachelor's degree                   118            118            118   118
# high school                         196            196            196   196
# master's degree                      59             59             59    59
# some college                        226            226            226   226
# some high school                    179            179            179   179
#
#                              lunch_cost  preparation_status
# parental level of education
# associate's degree                  222                 222
# bachelor's degree                   118                 118
# high school                         196                 196
# master's degree                      59                  59
# some college                        226                 226
# some high school                    179                 179

# %%
df_students['parents_education'] = df_students['parental level of education'].map({'some high school':1 , 'high school':2, 'some college':3, 'bachelor\'s degree': 4, 'associate\'s degree':5, 'master\'s degree':6})
df_students.head(5)
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score  male  lunch_cost  \
# 0          72             72             74     0           1
# 1          69             90             88     0           1
# 2          90             95             93     0           1
# 3          47             57             44     1           0
# 4          76             78             75     1           1
#
#    preparation_status  parents_education
# 0                   0                  4
# 1                   1                  3
# 2                   0                  6
# 3                   0                  5
# 4                   0                  3

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df_students.corr(), annot = True);

# %% [markdown]
# ## ***We have mapped above the parent educaion level to 6 numric values***

# %% [markdown]
# # well done! we can see all the corrolations above

# %%
plt.figure(figsize=(6,4))
plt.hist(df_students['math score'], bins=100, alpha=0.3, label="Maths score", facecolor ='r')
plt.xlabel("Score", size=14)
plt.ylabel("Dencity", size=14)
plt.title("distrbution of scores")
plt.legend(loc='upper right')

# %%
plt.figure(figsize=(6,4))
plt.hist(df_students['reading score'], bins=100, alpha=0.3, label="Reading score", facecolor = 'm')
plt.xlabel("Score", size=14)
plt.ylabel("Dencity", size=14)
plt.title("distrbution of scores")
plt.legend(loc='upper right')

# %%
plt.figure(figsize=(6,4))
plt.hist(df_students['writing score'], bins=100, alpha=0.3, label="Writing score", facecolor = 'g')
plt.xlabel("Score", size=14)
plt.ylabel("Dencity", size=14)
plt.title("distrbution of scores")
plt.legend(loc='upper right')

# %%
plt.figure(figsize=(13,8))

plt.hist(df_students['math score'], bins=100, alpha=0.3, label="Maths score", facecolor ='r')
plt.hist(df_students['reading score'], bins=100, alpha=0.3, label="Reading score", facecolor = 'm')
plt.hist(df_students['writing score'], bins=100, alpha=0.3, label="Writing score", facecolor = 'g')
plt.xlabel("Score", size=14)
plt.ylabel("Dencity", size=14)
plt.title("distrbution of scores")
plt.legend(loc='upper right')

# %% [markdown]
# # ***Above we have shown the distrebution of scores for maths , reading and wrighting as well ass together via histograms***

# %%
df_students.head()
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score  male  lunch_cost  \
# 0          72             72             74     0           1
# 1          69             90             88     0           1
# 2          90             95             93     0           1
# 3          47             57             44     1           0
# 4          76             78             75     1           1
#
#    preparation_status  parents_education
# 0                   0                  4
# 1                   1                  3
# 2                   0                  6
# 3                   0                  5
# 4                   0                  3

# %% [markdown]
# ### Above we have double checked our data and have verified our numric changes

# %%
X = df_students[['male','parents_education','lunch_cost','preparation_status','math score','reading score']]
y = df_students['writing score']

# %%
from sklearn import model_selection
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

#standard 20 %

# %%
from sklearn.linear_model import LinearRegression

# %%
modle = LinearRegression()
modle.fit(X_train, y_train)

score = modle.score(X_test, y_test)

print(score)
# Out:
# 0.9406657329584662

# %% [markdown]
# # Important anaylis
#
# ## ***Above we have split our data in to training and testing sets (using the standard 20/80) we have difined a modle of the type liner regresion and fit our modle with our training sets accordingly ***
#
# # ***Our model currently predicts with an accuracy score of 94.06% (our model estimates the writing score)***

# %%
joshua = [[1,6,1,1,90,50]]
print(modle.predict(joshua))
# Out:
# [63.23360523]

# %% [markdown]
# ## ***prediction for me***

# %%
modle.coef_
# Out:
# array([-5.99549175,  0.53774965,  0.2465896 ,  3.77106279,  0.28533911,
#         0.65352943])

# %% [markdown]
# ### ***above our our modles coef's also known as weights***

# %% [markdown]
# ## Above is a template of me and our model predicts i would recive a 58.92 in a writing test

# %% [markdown]
# # Lets try improve this, lets find the best test size for our model

# %%
lst_max_test_size = []
for i in np.arange(0.1,1,0.05):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state = 0)

    modle = LinearRegression()
    modle.fit(X_train, y_train)

    score = modle.score(X_test, y_test)
    
    lst_max_test_size.append(score)

# %%
plt.figure(figsize=(13,8))

plt.plot(np.arange(0.1,1,0.05),lst_max_test_size)
plt.xlabel("test size")
plt.ylabel("accuracy")
plt.title("accuracy as a function of test size")
# Out:
# Text(0.5, 1.0, 'accuracy as a function of test size')

# %% [markdown]
# ## ***It seems like at a 45/55 split test we would get the best results , lets try this***

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.45, random_state = 0)

modle = LinearRegression()
modle.fit(X_train, y_train)

score = modle.score(X_test, y_test)
    
print(score)
# Out:
# 0.9433650350182732

# %% [markdown]
# ### ***Our modle has improved by around 0.3% but we have compromized and it is better practice to use the 20/80 we shall therefor go back to that as it hass not been worth it***

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

modle = LinearRegression()
modle.fit(X_train, y_train)

score = modle.score(X_test, y_test)
    
print(score)
# Out:
# 0.9406657329584662

# %% [markdown]
# # K cross validation
#
# ### ***We want to validate that our model will be accurat on data it has not yet seen. One way of doing this is K cross validation where we will split our data randomly in to k amounts of "Folds" usally 5 or 10.***
#
# ### ***this gives us a good estimate about the accuracy of our model***

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
folds = KFold(n_splits = 5, shuffle = True, random_state = 100)
scores = cross_val_score(modle, X_train, y_train, scoring='r2', cv=folds)
scores
# Out:
# array([0.94164166, 0.93908449, 0.94542607, 0.93843693, 0.94049079])

# %% [markdown]
# #### ***Above we have split the data in to 5 k folds and we shall now take the average of these five results wich will be a good estimate of our models accuracy***

# %%
scores.mean()
# Out:
# 0.9410159869467826

# %% [markdown]
# ### ***Below we hsall try with 10 k folds***

# %%
folds = KFold(n_splits = 10, shuffle = True, random_state = 100)
scores = cross_val_score(modle, X_train, y_train, scoring='r2', cv=folds)
scores
# Out:
# array([0.94897067, 0.93315295, 0.93647927, 0.94156469, 0.94767066,
#        0.94129968, 0.94189483, 0.93456462, 0.94768692, 0.93104141])

# %%
scores.mean()
# Out:
# 0.9404325715538251

# %% [markdown]
# #### We can see a better indicator would be k = 5 for our folds and we can confirm our modle is reliable with an average of 93.69% accuracy

# %% [markdown]
# # The End
